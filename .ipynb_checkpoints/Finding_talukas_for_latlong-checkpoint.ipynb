# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
#os.chdir('/'.join(os.getcwd().split('/')[:-1]))
kernel_is_loaded = True

# %%
print(os.getcwd())
# Out:
# C:\Users\abhij\OneDrive\Desktop\Wadhwani\Working_with_shp_files

# %%
df=pd.read_csv("./crop_spectral_library_csv.csv",on_bad_lines='skip')

# %%
df.head()
# Out:
#     latitude  longitude           state district  taluka sowing_period  year  \
# 0  22.749243  76.285961  Madhya Pradesh    DEWAS     NaN        oct_2f  2023
# 1  22.823677  75.178438  Madhya Pradesh     DHAR     NaN        oct_2f  2023
# 2  22.823894  75.178496  Madhya Pradesh     DHAR     NaN        oct_2f  2023
# 3  23.746600  78.178934  Madhya Pradesh  VIDESHA     NaN        oct_2f  2023
# 4  22.521601  75.397578  Madhya Pradesh     DHAR     NaN        oct_2f  2023
#
#   crop_name ndvi_capture_period  ndvi_value  \
# 0     Wheat              jan_1f       181.0
# 1     Wheat              jan_1f       191.0
# 2     Wheat              jan_1f       191.0
# 3     Wheat              jan_1f       188.0
# 4     Wheat              jan_1f       195.0
#
#                                             location ndvi_capture_date  \
# 0  0101000020E6100000733CB02D4D1253406DBE5B6ACEBF...     0001-01-01 BC
# 1  0101000020E61000007C37CC866BCB52407DF8437DDCD2...     0001-01-01 BC
# 2  0101000020E610000040BDBE7B6CCB524011E335AFEAD2...     0001-01-01 BC
# 3  0101000020E6100000480845A9738B5340E32FD23021BF...     0001-01-01 BC
# 4  0101000020E6100000EFC517ED71D95240C713419C8785...     0001-01-01 BC
#
#       interval_range          sowing_year  sowing_date  harvest_yr  \
# 0  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022  15-10-2022
# 1  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022  15-10-2022
# 2  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022  15-10-2022
# 3  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022  15-10-2022
# 4  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022  15-10-2022
#
#    harvest_period     one
# 0            2023  feb_1f
# 1            2023  feb_1f
# 2            2023  feb_1f
# 3            2023  feb_1f
# 4            2023  feb_1f

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397031 entries, 0 to 397030
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   latitude             397031 non-null  float64
#  1   longitude            397031 non-null  float64
#  2   state                397031 non-null  object
#  3   district             397031 non-null  object
#  4   taluka               0 non-null       float64
#  5   sowing_period        397031 non-null  object
#  6   year                 397031 non-null  int64
#  7   crop_name            397031 non-null  object
#  8   ndvi_capture_period  397031 non-null  object
#  9   ndvi_value           198515 non-null  float64
#  10  location             397031 non-null  object
#  11  ndvi_capture_date    397031 non-null  object
#  12  interval_range       397031 non-null  object
#  13  sowing_year          397031 non-null  object
#  14  sowing_date          397031 non-null  int64
#  15  harvest_yr           397031 non-null  object
#  16  harvest_period       397031 non-null  int64
#  17  one                  397031 non-null  object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 54.5+ MB

# %%
import geopandas as gpd
from shapely.geometry import Point

# Convert longitude and latitude to a geometric Point object
df['location'] = df.apply(lambda row: Point(row.longitude, row.latitude), axis=1)

# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='location')

# %%
gdf.head()
# Out:
#     latitude  longitude           state district  taluka sowing_period  year  \
# 0  22.749243  76.285961  Madhya Pradesh    DEWAS     NaN        oct_2f  2023
# 1  22.823677  75.178438  Madhya Pradesh     DHAR     NaN        oct_2f  2023
# 2  22.823894  75.178496  Madhya Pradesh     DHAR     NaN        oct_2f  2023
# 3  23.746600  78.178934  Madhya Pradesh  VIDESHA     NaN        oct_2f  2023
# 4  22.521601  75.397578  Madhya Pradesh     DHAR     NaN        oct_2f  2023
#
#   crop_name ndvi_capture_period  ndvi_value                   location  \
# 0     Wheat              jan_1f       181.0  POINT (76.28596 22.74924)
# 1     Wheat              jan_1f       191.0  POINT (75.17844 22.82368)
# 2     Wheat              jan_1f       191.0  POINT (75.17850 22.82389)
# 3     Wheat              jan_1f       188.0  POINT (78.17893 23.74660)
# 4     Wheat              jan_1f       195.0  POINT (75.39758 22.52160)
#
#   ndvi_capture_date     interval_range          sowing_year  sowing_date  \
# 0     0001-01-01 BC  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022
# 1     0001-01-01 BC  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022
# 2     0001-01-01 BC  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022
# 3     0001-01-01 BC  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022
# 4     0001-01-01 BC  ['0001-01-01 BC'"  '"0001-01-14 BC'")"         2022
#
#    harvest_yr  harvest_period     one
# 0  15-10-2022            2023  feb_1f
# 1  15-10-2022            2023  feb_1f
# 2  15-10-2022            2023  feb_1f
# 3  15-10-2022            2023  feb_1f
# 4  15-10-2022            2023  feb_1f

# %%
fig, ax = plt.subplots()

# Plot points
gdf.plot(ax=ax, color='blue')

# %%
shp_file=gpd.read_file("./sub-district/SUBDISTRICT_BOUNDARY.shp")

# %%
shp_file.head()

# %%
shp_file.plot()
# Out:
# <Axes: >

# %%
latlong_with_talukas=gpd.sjoin(gdf,shp_file,how='inner',op='within')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_8030/3021117416.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: PROJCS["LCC_WGS84",GEOGCS["WGS 84",DATUM["WGS_1984 ...
#
#   latlong_with_talukas=gpd.sjoin(gdf,shp_file,how='inner',op='within')

# %%
gdf.crs

# %%
shp_file.crs
# Out:
# <Projected CRS: PROJCS["LCC_WGS84",GEOGCS["WGS 84",DATUM["WGS_1984 ...>
# Name: LCC_WGS84
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.crs = "epsg:4326"
gdf.to_crs("WGS84",inplace=True)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
shp_file.to_crs("WGS84",inplace=True)

# %%
shp_file.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
latlong_with_talukas=gpd.sjoin(gdf,shp_file,how='inner',op='within')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
latlong_with_talukas.head()
# Out:
#       latitude  longitude           state district  taluka sowing_period  \
# 0    26.235858  77.446783  Madhya Pradesh   MORENA     NaN        oct_2f
# 3    26.318233  77.451725  Madhya Pradesh   MORENA     NaN        nov_1f
# 120  26.316559  77.426170  Madhya Pradesh   MORENA     NaN        oct_2f
# 226  26.297585  77.427409  Madhya Pradesh   MORENA     NaN        oct_2f
# 264  26.270065  77.445427  Madhya Pradesh   MORENA     NaN        nov_1f
#
#      year crop_name ndvi_capture_period  ndvi_value  ... harvest_period  \
# 0    2023   Mustard              jan_1f       186.0  ...         feb_2f
# 3    2023   Mustard              jan_1f       180.0  ...         mar_2f
# 120  2023   Mustard              jan_1f       181.0  ...         mar_1f
# 226  2023   Mustard              jan_1f       185.0  ...         mar_1f
# 264  2023   Mustard              jan_1f       172.0  ...         mar_1f
#
#     index_right District           STATE     TEHSIL     Shape_Leng  \
# 0          2877   MORENA  MADHYA PRADESH  SABALGARH  179885.754262
# 3          2877   MORENA  MADHYA PRADESH  SABALGARH  179885.754262
# 120        2877   MORENA  MADHYA PRADESH  SABALGARH  179885.754262
# 226        2877   MORENA  MADHYA PRADESH  SABALGARH  179885.754262
# 264        2877   MORENA  MADHYA PRADESH  SABALGARH  179885.754262
#
#        Shape_Area       test  Dist_1   Tehsil_1
# 0    7.413193e+08  SABALGARH  MORENA  SABALGARH
# 3    7.413193e+08  SABALGARH  MORENA  SABALGARH
# 120  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 226  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 264  7.413193e+08  SABALGARH  MORENA  SABALGARH
#
# [5 rows x 26 columns]

# %%
latlong_with_talukas.drop(['taluka','District','STATE','','Dist_1'],axis=1)
# Out:
#         latitude  longitude           state district sowing_period  year  \
# 0      26.235858  77.446783  Madhya Pradesh   MORENA        oct_2f  2023
# 3      26.318233  77.451725  Madhya Pradesh   MORENA        nov_1f  2023
# 120    26.316559  77.426170  Madhya Pradesh   MORENA        oct_2f  2023
# 226    26.297585  77.427409  Madhya Pradesh   MORENA        oct_2f  2023
# 264    26.270065  77.445427  Madhya Pradesh   MORENA        nov_1f  2023
# ...          ...        ...             ...      ...           ...   ...
# 25676  24.143728  80.403746  Madhya Pradesh    PANNA        nov_2f  2022
# 26961  24.143728  80.403746  Madhya Pradesh    PANNA        nov_2f  2022
# 28246  24.143728  80.403746  Madhya Pradesh    PANNA        nov_2f  2022
# 29531  24.143728  80.403746  Madhya Pradesh    PANNA        nov_2f  2022
# 30816  24.143728  80.403746  Madhya Pradesh    PANNA        nov_2f  2022
#
#       crop_name ndvi_capture_period  ndvi_value                   location  \
# 0       Mustard              jan_1f       186.0  POINT (77.44678 26.23586)
# 3       Mustard              jan_1f       180.0  POINT (77.45172 26.31823)
# 120     Mustard              jan_1f       181.0  POINT (77.42617 26.31656)
# 226     Mustard              jan_1f       185.0  POINT (77.42741 26.29759)
# 264     Mustard              jan_1f       172.0  POINT (77.44543 26.27006)
# ...         ...                 ...         ...                        ...
# 25676   Mustard              oct_2f       125.0  POINT (80.40375 24.14373)
# 26961   Mustard              nov_1f       122.0  POINT (80.40375 24.14373)
# 28246   Mustard              nov_2f       127.0  POINT (80.40375 24.14373)
# 29531   Mustard              dec_1f       144.0  POINT (80.40375 24.14373)
# 30816   Mustard              dec_2f       160.0  POINT (80.40375 24.14373)
#
#        ...           interval_range sowing_year  sowing_date harvest_yr  \
# 0      ...  [2023-01-01,2023-01-14)        2022   2022-10-15       2023
# 3      ...  [2023-01-01,2023-01-14)        2022   2022-11-01       2023
# 120    ...  [2023-01-01,2023-01-14)        2022   2022-10-15       2023
# 226    ...  [2023-01-01,2023-01-14)        2022   2022-10-15       2023
# 264    ...  [2023-01-01,2023-01-14)        2022   2022-11-01       2023
# ...    ...                      ...         ...          ...        ...
# 25676  ...  [2022-10-15,2022-10-31)        2022   2022-11-15       2023
# 26961  ...  [2022-11-01,2022-11-14)        2022   2022-11-15       2023
# 28246  ...  [2022-11-15,2022-11-30)        2022   2022-11-15       2023
# 29531  ...  [2022-12-01,2022-12-14)        2022   2022-11-15       2023
# 30816  ...  [2022-12-15,2022-12-31)        2022   2022-11-15       2023
#
#        harvest_period index_right     TEHSIL       test  Dist_1     Tehsil
# 0              feb_2f        2877  SABALGARH  SABALGARH  MORENA  SABALGARH
# 3              mar_2f        2877  SABALGARH  SABALGARH  MORENA  SABALGARH
# 120            mar_1f        2877  SABALGARH  SABALGARH  MORENA  SABALGARH
# 226            mar_1f        2877  SABALGARH  SABALGARH  MORENA  SABALGARH
# 264            mar_1f        2877  SABALGARH  SABALGARH  MORENA  SABALGARH
# ...               ...         ...        ...        ...     ...        ...
# 25676          feb_1f        2887  SH>HNAGAR  SHAHNAGAR   PANNA  SHAHNAGAR
# 26961          feb_1f        2887  SH>HNAGAR  SHAHNAGAR   PANNA  SHAHNAGAR
# 28246          feb_1f        2887  SH>HNAGAR  SHAHNAGAR   PANNA  SHAHNAGAR
# 29531          feb_1f        2887  SH>HNAGAR  SHAHNAGAR   PANNA  SHAHNAGAR
# 30816          feb_1f        2887  SH>HNAGAR  SHAHNAGAR   PANNA  SHAHNAGAR
#
# [30839 rows x 21 columns]

# %%
latlong_with_talukas.rename(columns = {'Tehsil_1':'Tehsil'}, inplace = True)

# %%
# Specify the path where you want to save the CSV file
output_csv_path = "./Abhijeeth/Working_with_shp_files/crop_spectral_library_with_Tehsil_csv.csv"

# Write the GeoPandas DataFrame to the CSV file
latlong_with_talukas.to_csv(output_csv_path, index=False)

# %%
gdf.info
# Out:
# <bound method DataFrame.info of         latitude  longitude           state    district  taluka sowing_period  \
# 0      26.235858  77.446783  Madhya Pradesh      MORENA     NaN        oct_2f
# 1      26.162953  77.120647  Madhya Pradesh     SHEOPUR     NaN        nov_1f
# 2      26.223129  77.607418  Madhya Pradesh      MORENA     NaN        oct_2f
# 3      26.318233  77.451725  Madhya Pradesh      MORENA     NaN        nov_1f
# 4      25.577871  76.582049  Madhya Pradesh     SHEOPUR     NaN        oct_2f
# ...          ...        ...             ...         ...     ...           ...
# 30834  24.769333  77.794757  Madhya Pradesh  ASHOKNAGAR     NaN        nov_1f
# 30835  25.337278  77.565566  Madhya Pradesh    SHIVPURI     NaN        nov_1f
# 30836  23.886489  76.148996  Madhya Pradesh  AGAR-MALWA     NaN        nov_1f
# 30837  23.886476  76.148988  Madhya Pradesh  AGAR-MALWA     NaN        nov_1f
# 30838  23.711413  76.539161  Madhya Pradesh     RAJGARH     NaN        nov_1f
#
#        year crop_name ndvi_capture_period  ndvi_value  \
# 0      2023   Mustard              jan_1f       186.0
# 1      2023   Mustard              jan_1f       186.0
# 2      2023   Mustard              jan_1f       181.0
# 3      2023   Mustard              jan_1f       180.0
# 4      2023   Mustard              jan_1f       184.0
# ...     ...       ...                 ...         ...
# 30834  2022   Mustard              dec_2f       160.0
# 30835  2022   Mustard              dec_2f       194.0
# 30836  2022   Mustard              dec_2f       170.0
# 30837  2022   Mustard              dec_2f       170.0
# 30838  2022   Mustard              dec_2f       178.0
#
#                         location ndvi_capture_date           interval_range  \
# 0      POINT (77.44678 26.23586)        2023-01-01  [2023-01-01,2023-01-14)
# 1      POINT (77.12065 26.16295)        2023-01-01  [2023-01-01,2023-01-14)
# 2      POINT (77.60742 26.22313)        2023-01-01  [2023-01-01,2023-01-14)
# 3      POINT (77.45172 26.31823)        2023-01-01  [2023-01-01,2023-01-14)
# 4      POINT (76.58205 25.57787)        2023-01-01  [2023-01-01,2023-01-14)
# ...                          ...               ...                      ...
# 30834  POINT (77.79476 24.76933)        2022-12-15  [2022-12-15,2022-12-31)
# 30835  POINT (77.56557 25.33728)        2022-12-15  [2022-12-15,2022-12-31)
# 30836  POINT (76.14900 23.88649)        2022-12-15  [2022-12-15,2022-12-31)
# 30837  POINT (76.14899 23.88648)        2022-12-15  [2022-12-15,2022-12-31)
# 30838  POINT (76.53916 23.71141)        2022-12-15  [2022-12-15,2022-12-31)
#
#        sowing_year sowing_date  harvest_yr harvest_period  \
# 0             2022  2022-10-15        2023         feb_2f
# 1             2022  2022-11-01        2023         mar_1f
# 2             2022  2022-10-15        2023         mar_2f
# 3             2022  2022-11-01        2023         mar_2f
# 4             2022  2022-10-15        2023         mar_1f
# ...            ...         ...         ...            ...
# 30834         2022  2022-11-01        2023         mar_1f
# 30835         2022  2022-11-01        2023         mar_1f
# 30836         2022  2022-11-01        2023         feb_1f
# 30837         2022  2022-11-01        2023         feb_1f
# 30838         2022  2022-11-01        2023         feb_2f
#
#                         geometry
# 0      POINT (77.44678 26.23586)
# 1      POINT (77.12065 26.16295)
# 2      POINT (77.60742 26.22313)
# 3      POINT (77.45172 26.31823)
# 4      POINT (76.58205 25.57787)
# ...                          ...
# 30834  POINT (77.79476 24.76933)
# 30835  POINT (77.56557 25.33728)
# 30836  POINT (76.14900 23.88649)
# 30837  POINT (76.14899 23.88648)
# 30838  POINT (76.53916 23.71141)
#
# [30839 rows x 18 columns]>

# %%
latlong_with_talukas.info
# Out:
# <bound method DataFrame.info of         latitude  longitude           state district  taluka sowing_period  \
# 0      26.235858  77.446783  Madhya Pradesh   MORENA     NaN        oct_2f
# 3      26.318233  77.451725  Madhya Pradesh   MORENA     NaN        nov_1f
# 120    26.316559  77.426170  Madhya Pradesh   MORENA     NaN        oct_2f
# 226    26.297585  77.427409  Madhya Pradesh   MORENA     NaN        oct_2f
# 264    26.270065  77.445427  Madhya Pradesh   MORENA     NaN        nov_1f
# ...          ...        ...             ...      ...     ...           ...
# 25676  24.143728  80.403746  Madhya Pradesh    PANNA     NaN        nov_2f
# 26961  24.143728  80.403746  Madhya Pradesh    PANNA     NaN        nov_2f
# 28246  24.143728  80.403746  Madhya Pradesh    PANNA     NaN        nov_2f
# 29531  24.143728  80.403746  Madhya Pradesh    PANNA     NaN        nov_2f
# 30816  24.143728  80.403746  Madhya Pradesh    PANNA     NaN        nov_2f
#
#        year crop_name ndvi_capture_period  ndvi_value  ...  \
# 0      2023   Mustard              jan_1f       186.0  ...
# 3      2023   Mustard              jan_1f       180.0  ...
# 120    2023   Mustard              jan_1f       181.0  ...
# 226    2023   Mustard              jan_1f       185.0  ...
# 264    2023   Mustard              jan_1f       172.0  ...
# ...     ...       ...                 ...         ...  ...
# 25676  2022   Mustard              oct_2f       125.0  ...
# 26961  2022   Mustard              nov_1f       122.0  ...
# 28246  2022   Mustard              nov_2f       127.0  ...
# 29531  2022   Mustard              dec_1f       144.0  ...
# 30816  2022   Mustard              dec_2f       160.0  ...
#
#                         geometry index_right District           STATE  \
# 0      POINT (77.44678 26.23586)        2877   MORENA  MADHYA PRADESH
# 3      POINT (77.45172 26.31823)        2877   MORENA  MADHYA PRADESH
# 120    POINT (77.42617 26.31656)        2877   MORENA  MADHYA PRADESH
# 226    POINT (77.42741 26.29759)        2877   MORENA  MADHYA PRADESH
# 264    POINT (77.44543 26.27006)        2877   MORENA  MADHYA PRADESH
# ...                          ...         ...      ...             ...
# 25676  POINT (80.40375 24.14373)        2887    PANNA  MADHYA PRADESH
# 26961  POINT (80.40375 24.14373)        2887    PANNA  MADHYA PRADESH
# 28246  POINT (80.40375 24.14373)        2887    PANNA  MADHYA PRADESH
# 29531  POINT (80.40375 24.14373)        2887    PANNA  MADHYA PRADESH
# 30816  POINT (80.40375 24.14373)        2887    PANNA  MADHYA PRADESH
#
#           TEHSIL     Shape_Leng    Shape_Area       test  Dist_1   Tehsil_1
# 0      SABALGARH  179885.754262  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 3      SABALGARH  179885.754262  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 120    SABALGARH  179885.754262  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 226    SABALGARH  179885.754262  7.413193e+08  SABALGARH  MORENA  SABALGARH
# 264    SABALGARH  179885.754262  7.413193e+08  SABALGARH  MORENA  SABALGARH
# ...          ...            ...           ...        ...     ...        ...
# 25676  SH>HNAGAR  447109.879181  1.701986e+09  SHAHNAGAR   PANNA  SHAHNAGAR
# 26961  SH>HNAGAR  447109.879181  1.701986e+09  SHAHNAGAR   PANNA  SHAHNAGAR
# 28246  SH>HNAGAR  447109.879181  1.701986e+09  SHAHNAGAR   PANNA  SHAHNAGAR
# 29531  SH>HNAGAR  447109.879181  1.701986e+09  SHAHNAGAR   PANNA  SHAHNAGAR
# 30816  SH>HNAGAR  447109.879181  1.701986e+09  SHAHNAGAR   PANNA  SHAHNAGAR
#
# [30839 rows x 27 columns]>
